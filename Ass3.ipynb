# %%
#Apply appropriate ML algorithm on a dataset collected in a cosmetics shop showing details of customers to predict customer response for special offers.

# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv(r"Salary_dataset.csv")

# %%
ds.head()
# Out:
#    Sr.No  YearsExperience  Salary
# 0      0              1.2   39344
# 1      1              1.4   46206
# 2      2              1.6   37732
# 3      3              2.1   43526
# 4      4              2.3   39892

# %%
ds = pd.get_dummies(ds, columns=["Salary"])

# %%
ds.head()
# Out:
#    Sr.No  YearsExperience  Salary_37732  Salary_39344  Salary_39892  \
# 0      0              1.2         False          True         False
# 1      1              1.4         False         False         False
# 2      2              1.6          True         False         False
# 3      3              2.1         False         False         False
# 4      4              2.3         False         False          True
#
#    Salary_43526  Salary_46206  Salary_54446  Salary_55795  Salary_56643  ...  \
# 0         False         False         False         False         False  ...
# 1         False          True         False         False         False  ...
# 2         False         False         False         False         False  ...
# 3          True         False         False         False         False  ...
# 4         False         False         False         False         False  ...
#
#    Salary_93941  Salary_98274  Salary_101303  Salary_105583  Salary_109432  \
# 0         False         False          False          False          False
# 1         False         False          False          False          False
# 2         False         False          False          False          False
# 3         False         False          False          False          False
# 4         False         False          False          False          False
#
#    Salary_112636  Salary_113813  Salary_116970  Salary_121873  Salary_122392
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
# [5 rows x 32 columns]

# %%
X = ds.iloc[:, [0,1,2,4,5]]
y = ds.iloc[:, [3]]

# %%
y
# Out:
#     Salary_39344
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False

# %%
X
# Out:
#     Sr.No  YearsExperience  Salary_37732  Salary_39892  Salary_43526
# 0       0              1.2         False         False         False
# 1       1              1.4         False         False         False
# 2       2              1.6          True         False         False
# 3       3              2.1         False         False          True
# 4       4              2.3         False          True         False
# 5       5              3.0         False         False         False
# 6       6              3.1         False         False         False
# 7       7              3.3         False         False         False
# 8       8              3.3         False         False         False
# 9       9              3.8         False         False         False
# 10     10              4.0         False         False         False
# 11     11              4.1         False         False         False
# 12     12              4.1         False         False         False
# 13     13              4.2         False         False         False
# 14     14              4.6         False         False         False
# 15     15              5.0         False         False         False
# 16     16              5.2         False         False         False
# 17     17              5.4         False         False         False
# 18     18              6.0         False         False         False
# 19     19              6.1         False         False         False
# 20     20              6.9         False         False         False
# 21     21              7.2         False         False         False
# 22     22              8.0         False         False         False
# 23     23              8.3         False         False         False
# 24     24              8.8         False         False         False
# 25     25              9.1         False         False         False
# 26     26              9.6         False         False         False
# 27     27              9.7         False         False         False
# 28     28             10.4         False         False         False
# 29     29             10.6         False         False         False

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, y_Train, y_Test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = "linear", random_state = 0)

# %%
classifier.fit(X_Train, y_Train)
# Out:
# c:\Users\samik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_Test)

# %%
from sklearn import metrics

# %%
y_Test = np.array(y_Test, dtype=float)
y_pred = np.array(y_pred, dtype=float)

print("Mean absolute error: ", metrics.mean_absolute_error(y_Test, y_pred))
print("Mean squared error: ", metrics.mean_squared_error(y_Test, y_pred))
print("R2 score: ", metrics.r2_score(y_Test, y_pred))
# Out:
# Mean absolute error:  0.0
# Mean squared error:  0.0
# R2 score:  1.0
